# %%
import pandas as pd

house = pd.read_csv('Housing.csv')
print(house.to_string)
# Out:
# <bound method DataFrame.to_string of         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
# ...

# %%
aa = pd.DataFrame(house)
aa
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
aa[["price","area"]]
# Out:
#         price  area
# 0    13300000  7420
# 1    12250000  8960
# 2    12250000  9960
# 3    12215000  7500
# 4    11410000  7420
# ..        ...   ...
# 540   1820000  3000
# 541   1767150  2400
# 542   1750000  3620
# 543   1750000  2910
# 544   1750000  3850
#
# [545 rows x 2 columns]

# %%
aa.dropna().value_counts()
# Out:
# price     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1750000   2910  3         1          1        no        no         no        no               no               0        no        furnished           1
#           3620  2         1          1        yes       no         no        no               no               0        no        unfurnished         1
#           3850  3         1          2        yes       no         no        no               no               0        no        unfurnished         1
# 1767150   2400  3         1          1        no        no         no        no               no               0        no        semi-furnished      1
# 1820000   3000  2         1          1        yes       no         yes       no               no               2        no        unfurnished         1
# ...

# %%
aa.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
aa.shape
# Out:
# (545, 13)

# %%
aa[aa["area"]>=2800]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 539   1855000  2990         2          1        1       no        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
aa.loc[0:2,["price","area"]]
# Out:
#       price  area
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960

# %%
aa.groupby("area").max()
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# area
# 1650    3150000         3          1        2       no        no      yes
# 1700    1890000         3          1        2      yes        no       no
# 1836    2275000         2          1        1       no        no      yes
# 1905    4340000         5          1        2       no        no      yes
# 1950    3430000         3          2        2      yes        no      yes
# ...         ...       ...        ...      ...      ...       ...      ...
# 12900   4900000         3          1        1      yes        no       no
# 12944   3500000         3          1        1      yes        no       no
# 13200   9800000         3          1        2      yes        no      yes
# 15600   5943000         3          1        1      yes        no       no
# 16200  10150000         5          3        2      yes        no       no
#
#       hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
aa["area"] = aa["area"]+1
aa
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7421         4          2        3      yes        no       no
# 1    12250000  8961         4          4        4      yes        no       no
# 2    12250000  9961         3          2        2      yes        no      yes
# 3    12215000  7501         4          2        2      yes        no      yes
# 4    11410000  7421         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3001         2          1        1      yes        no      yes
# 541   1767150  2401         3          1        1       no        no       no
# 542   1750000  3621         2          1        1      yes        no       no
# 543   1750000  2911         3          1        1       no        no       no
# 544   1750000  3851         3          1        2      yes        no       no
#
# ...

# %%
aa.drop_duplicates().value_counts()
# Out:
# price     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1750000   2911  3         1          1        no        no         no        no               no               0        no        furnished           1
#           3621  2         1          1        yes       no         no        no               no               0        no        unfurnished         1
#           3851  3         1          2        yes       no         no        no               no               0        no        unfurnished         1
# 1767150   2401  3         1          1        no        no         no        no               no               0        no        semi-furnished      1
# 1820000   3001  2         1          1        yes       no         yes       no               no               2        no        unfurnished         1
# ...

# %%
aa.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object
